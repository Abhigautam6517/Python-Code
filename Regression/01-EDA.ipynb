# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# absolute path v/s relative path

# %%
df = pd.read_csv(r"E:\TCS\final.csv")

# %%
df.shape
# Out:
# (622489, 23)

# %%
df.head()
# Out:
#    id    time orig_time first_time mat_time  balance_time   LTV_time  \
# 0   1  2007Q1    1999Q1     2007Q1   2029Q1      41303.42  24.498336
# 1   1  2007Q2    1999Q1     2007Q1   2029Q1      41061.95  24.483867
# 2   1  2007Q3    1999Q1     2007Q1   2029Q1      40804.42  24.626795
# 3   1  2007Q4    1999Q1     2007Q1   2029Q1      40483.89  24.735883
# 4   1  2008Q1    1999Q1     2007Q1   2029Q1      40367.06  24.925476
#
#    interest_rate_time  gdp_time  REtype_CO_orig_time  ...  balance_orig_time  \
# 0                 9.2  2.899137                    0  ...            45000.0
# 1                 9.2  2.151365                    0  ...            45000.0
# 2                 9.2  2.361722                    0  ...            45000.0
# 3                 9.2  1.229172                    0  ...            45000.0
# 4                 9.2  1.692969                    0  ...            45000.0
#
#    FICO_orig_time  LTV_orig_time  Interest_Rate_orig_time  hpi_orig_time  \
# ...

# %%
df.tail()
# Out:
#            id    time orig_time first_time mat_time  balance_time   LTV_time  \
# 622484  50000  2014Q4    2004Q4     2013Q4   2045Q1     517107.42  57.659403
# 622485  50000  2015Q1    2004Q4     2013Q4   2045Q1     512274.57  55.359916
# 622486  50000  2015Q2    2004Q4     2013Q4   2045Q1     507396.72  54.492206
# 622487  50000  2015Q3    2004Q4     2013Q4   2045Q1     502478.87  54.171106
# 622488  50000  2015Q4    2004Q4     2013Q4   2045Q1     497521.35  53.023479
#
#         interest_rate_time  gdp_time  REtype_CO_orig_time  ...  \
# 622484               2.664  1.717053                    1  ...
# 622485               2.652  2.556052                    1  ...
# 622486               2.644  2.868594                    1  ...
# 622487               2.638  2.443648                    1  ...
# 622488               2.635  2.836358                    1  ...
#
#         balance_orig_time  FICO_orig_time  LTV_orig_time  \
# 622484           664000.0             653           80.0
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# time                         0
# orig_time                    0
# first_time                   0
# mat_time                     0
# balance_time                 0
# LTV_time                   270
# interest_rate_time           0
# gdp_time                     0
# REtype_CO_orig_time          0
# REtype_PU_orig_time          0
# REtype_SF_orig_time          0
# investor_orig_time           0
# balance_orig_time            0
# FICO_orig_time               0
# LTV_orig_time                0
# Interest_Rate_orig_time      0
# hpi_orig_time                0
# default_time                 0
# payoff_time                  0
# status_time                  0
# USSTHPI                      0
# UNRATE                       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622489 entries, 0 to 622488
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       622489 non-null  int64
#  1   time                     622489 non-null  object
#  2   orig_time                622489 non-null  object
#  3   first_time               622489 non-null  object
#  4   mat_time                 622489 non-null  object
#  5   balance_time             622489 non-null  float64
#  6   LTV_time                 622219 non-null  float64
#  7   interest_rate_time       622489 non-null  float64
#  8   gdp_time                 622489 non-null  float64
#  9   REtype_CO_orig_time      622489 non-null  int64
#  10  REtype_PU_orig_time      622489 non-null  int64
#  11  REtype_SF_orig_time      622489 non-null  int64
#  12  investor_orig_time       622489 non-null  int64
# ...

# %%
df.describe(include="all")
# Out:
#                    id    time orig_time first_time mat_time  balance_time  \
# count   622489.000000  622489    622489     622489   622489  6.224890e+05
# unique            NaN      60        98         50      202           NaN
# top               NaN  2008Q2    2007Q1     2007Q1   2036Q2           NaN
# freq              NaN   25906     57852      58978    46647           NaN
# mean     25147.492561     NaN       NaN        NaN      NaN  2.459649e+05
# std      13750.200051     NaN       NaN        NaN      NaN  2.141563e+05
# min          1.000000     NaN       NaN        NaN      NaN  0.000000e+00
# 25%      13580.000000     NaN       NaN        NaN      NaN  1.020174e+05
# 50%      24881.000000     NaN       NaN        NaN      NaN  1.806183e+05
# 75%      37045.000000     NaN       NaN        NaN      NaN  3.374950e+05
# max      50000.000000     NaN       NaN        NaN      NaN  8.701859e+06
#
#              LTV_time  interest_rate_time       gdp_time  REtype_CO_orig_time  \
# ...

# %%
len(df["id"].unique())
# Out:
# 50000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
enc.fit_transform(df["orig_time"])
# Out:
# array([31, 31, 31, ..., 54, 54, 54])

# %%
df["orig_time"] = enc.fit_transform(df["orig_time"])

# %%
df["mat_time"] = enc.fit_transform(df["mat_time"])

# %%
df.head()
# Out:
#    id    time  orig_time first_time  mat_time  balance_time   LTV_time  \
# 0   1  2007Q1         31     2007Q1        93      41303.42  24.498336
# 1   1  2007Q2         31     2007Q1        93      41061.95  24.483867
# 2   1  2007Q3         31     2007Q1        93      40804.42  24.626795
# 3   1  2007Q4         31     2007Q1        93      40483.89  24.735883
# 4   1  2008Q1         31     2007Q1        93      40367.06  24.925476
#
#    interest_rate_time  gdp_time  REtype_CO_orig_time  ...  balance_orig_time  \
# 0                 9.2  2.899137                    0  ...            45000.0
# 1                 9.2  2.151365                    0  ...            45000.0
# 2                 9.2  2.361722                    0  ...            45000.0
# 3                 9.2  1.229172                    0  ...            45000.0
# 4                 9.2  1.692969                    0  ...            45000.0
#
#    FICO_orig_time  LTV_orig_time  Interest_Rate_orig_time  hpi_orig_time  \
# ...

# %%
df["loan_tenure"] = df["mat_time"] - df["orig_time"]

# %%
df.groupby("id")["loan_tenure"].max().sort_values()
# Out:
# id
# 13374    -56
# 13364    -55
# 13382    -54
# 13421    -52
# 48163    -49
#         ...
# 25905    135
# 41100    136
# 16595    138
# 17484    141
# 12487    143
# Name: loan_tenure, Length: 50000, dtype: int32

# %%
df[df["LTV_time"].isna()==True].loc[511121, :]
# Out:
# id                            39722
# time                         2007Q1
# orig_time                        44
# first_time                   2007Q1
# mat_time                        106
# balance_time               97305.61
# LTV_time                        NaN
# interest_rate_time            11.35
# gdp_time                   2.899137
# REtype_CO_orig_time               0
# REtype_PU_orig_time               0
# REtype_SF_orig_time               1
# investor_orig_time                0
# balance_orig_time               0.0
# FICO_orig_time                  530
# LTV_orig_time                  80.0
# Interest_Rate_orig_time       11.35
# hpi_orig_time                122.89
# default_time                      0
# payoff_time                       0
# status_time                       0
# USSTHPI                      380.86
# UNRATE                          4.5
# loan_tenure                      62
# Name: 511121, dtype: object

# %%
df.groupby("time")["UNRATE"].mean().plot(kind="line")
plt.show()

# %%
df.groupby("time")["USSTHPI"].mean().plot(kind="line")

# %%
df.groupby('FICO_orig_time')["default_time"].sum().plot(kind="line")

# %%
def_rate = df.groupby('FICO_orig_time')["default_time"].sum() / df.groupby('FICO_orig_time')["default_time"].count()

# %%
def_rate.plot(kind="line")
plt.show()

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True)
